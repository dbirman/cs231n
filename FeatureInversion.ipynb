# %%
import numpy as np

#from assets.keras.keras.datasets import shapes_3d
from assets.keras.keras.preprocessing.image import ImageDataGenerator
from assets.keras.keras.models import Sequential
from assets.keras.keras.layers.core import Dense, Dropout, Activation, Flatten
from assets.keras.keras.layers.convolutional import Convolution3D, MaxPooling3D, ZeroPadding3D
from assets.keras.keras.layers.normalization import BatchNormalization
from assets.keras.keras.optimizers import SGD, RMSprop, Adam
from assets.keras.keras.utils import np_utils, generic_utils
from assets.keras.keras.regularizers import l2
from assets.keras.keras.callbacks import EarlyStopping, ModelCheckpoint
from assets.validation import *
from assets.vis_utils import *
import theano
import matplotlib.pyplot as plt
from matplotlib.pyplot import imsave
import math
from assets.vis_utils import *
from matplotlib import cm

# %matplotlib nbagg
# %load_ext autoreload
# %autoreload 2

#load dataset from gen_dataset
import cPickle as pickle

from assets.saveloadmodel import loadmodel
modelid = 300
thismodel = loadmodel(modelid)

fpath = os.getcwd() + "/figures/featureinversion/"
ipath = fpath + "mt_imgs/"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-f04280248874> in <module>()
#      29 from assets.saveloadmodel import loadmodel
#      30 modelid = 300
# ---> 31 thismodel = loadmodel(modelid)
#      32
#      33 fpath = os.getcwd() + "/figures/featureinversion/"
#
# /root/assignment2/motnet/assets/saveloadmodel.pyc in loadmodel(modelid)
#      43         fpa = os.getcwd()+'/assets/model/mymodel'+str(modelid)+'.json'
#      44         fpw = os.getcwd()+'/assets/model/mymodelweights'+str(modelid)+'.h5'
# ---> 45         model = model_from_json(open(fpa).read())
#      46         model.load_weights(fpw)
#      47         return model
#
# /root/assignment2/motnet/assets/keras/keras/models.pyc in model_from_json(json_string, custom_objects)
#     164     import json
#     165     config = json.loads(json_string)
# --> 166     return model_from_config(config, custom_objects=custom_objects)
#     167
#     168
#
# /root/assignment2/motnet/assets/keras/keras/models.pyc in model_from_config(config, custom_objects)
#     205             sample_weight_mode = config.get('sample_weight_mode')
#     206             model.compile(loss=loss, optimizer=optimizer,
# --> 207                           class_mode=class_mode, sample_weight_mode=sample_weight_mode)
#     208         elif model_name == 'Graph':
#     209             sample_weight_modes = config.get('sample_weight_modes', {})
#
# /root/assignment2/motnet/assets/keras/keras/models.pyc in compile(self, optimizer, loss, class_mode, sample_weight_mode)
#     514
#     515         self._train = K.function(train_ins, [train_loss], updates=updates)
# --> 516         self._train_with_acc = K.function(train_ins, [train_loss, train_accuracy], updates=updates)
#     517         self._predict = K.function(predict_ins, [self.y_test], updates=self.state_updates)
#     518         self._test = K.function(test_ins, [test_loss], updates=self.state_updates)
#
# /root/assignment2/motnet/assets/keras/keras/backend/theano_backend.pyc in function(inputs, outputs, updates)
#     445
#     446 def function(inputs, outputs, updates=[]):
# --> 447     return Function(inputs, outputs, updates=updates)
#     448
#     449
#
# /root/assignment2/motnet/assets/keras/keras/backend/theano_backend.pyc in __init__(self, inputs, outputs, updates, **kwargs)
#     437     def __init__(self, inputs, outputs, updates=[], **kwargs):
#     438         self.function = theano.function(inputs, outputs, updates=updates,
# --> 439                                         allow_input_downcast=True, **kwargs)
#     440
#     441     def __call__(self, inputs):
#
# /root/anaconda2/lib/python2.7/site-packages/theano/compile/function.pyc in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     316                    on_unused_input=on_unused_input,
#     317                    profile=profile,
# --> 318                    output_keys=output_keys)
#     319     # We need to add the flag check_aliased inputs if we have any mutable or
#     320     # borrowed used defined inputs
#
# /root/anaconda2/lib/python2.7/site-packages/theano/compile/pfunc.pyc in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     477                          accept_inplace=accept_inplace, name=name,
#     478                          profile=profile, on_unused_input=on_unused_input,
# --> 479                          output_keys=output_keys)
#     480
#     481
#
# /root/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1774                    profile=profile,
#    1775                    on_unused_input=on_unused_input,
# -> 1776                    output_keys=output_keys).create(
#    1777             defaults)
#    1778
#
# /root/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in __init__(self, inputs, outputs, mode, accept_inplace, function_builder, profile, on_unused_input, fgraph, output_keys)
#    1454                         optimizer, inputs, outputs)
#    1455                 else:
# -> 1456                     optimizer_profile = optimizer(fgraph)
#    1457
#    1458                 end_optimizer = time.time()
#
# /root/anaconda2/lib/python2.7/site-packages/theano/gof/opt.pyc in __call__(self, fgraph)
#      99
#     100         """
# --> 101         return self.optimize(fgraph)
#     102
#     103     def add_requirements(self, fgraph):
#
# /root/anaconda2/lib/python2.7/site-packages/theano/gof/opt.pyc in optimize(self, fgraph, *args, **kwargs)
#      87             orig = theano.tensor.basic.constant.enable
#      88             theano.tensor.basic.constant.enable = False
# ---> 89             ret = self.apply(fgraph, *args, **kwargs)
#      90         finally:
#      91             theano.tensor.basic.constant.enable = orig
#
# /root/anaconda2/lib/python2.7/site-packages/theano/gof/opt.pyc in apply(self, fgraph)
#     228             try:
#     229                 t0 = time.time()
# --> 230                 sub_prof = optimizer.optimize(fgraph)
#     231                 l.append(float(time.time() - t0))
#     232                 sub_profs.append(sub_prof)
#
# /root/anaconda2/lib/python2.7/site-packages/theano/gof/opt.pyc in optimize(self, fgraph, *args, **kwargs)
#      87             orig = theano.tensor.basic.constant.enable
#      88             theano.tensor.basic.constant.enable = False
# ---> 89             ret = self.apply(fgraph, *args, **kwargs)
#      90         finally:
#      91             theano.tensor.basic.constant.enable = orig
#
# /root/anaconda2/lib/python2.7/site-packages/theano/gof/opt.pyc in apply(self, fgraph, start_from)
#    2239             # apply clean up as final opt can have done changes that
#    2240             # request that
# -> 2241             changed |= apply_cleanup(iter_cleanup_sub_profs)
#    2242             # merge clean up profiles during that iteration.
#    2243             c_sub_profs = []
#
# /root/anaconda2/lib/python2.7/site-packages/theano/gof/opt.pyc in apply_cleanup(profs_dict)
#    2117                 nb = change_tracker.nb_imported
#    2118                 t_opt = time.time()
# -> 2119                 sub_prof = copt.apply(fgraph)
#    2120                 time_opts[copt] += time.time() - t_opt
#    2121                 profs_dict[copt].append(sub_prof)
#
# /root/anaconda2/lib/python2.7/site-packages/theano/gof/opt.pyc in apply(self, fgraph)
#     815
#     816                 try:
# --> 817                     fgraph.replace_all_validate(pairs, 'MergeOptimizer')
#     818                 except InconsistencyError:
#     819                     success = False
#
# /root/anaconda2/lib/python2.7/site-packages/theano/gof/toolbox.pyc in replace_all_validate(self, fgraph, replacements, reason, verbose)
#     304         for r, new_r in replacements:
#     305             try:
# --> 306                 fgraph.replace(r, new_r, reason=reason, verbose=False)
#     307             except Exception as e:
#     308                 msg = str(e)
#
# /root/anaconda2/lib/python2.7/site-packages/theano/gof/fg.pyc in replace(self, r, new_r, reason, verbose)
#     590         for node, i in list(r.clients):  # copy the client list for iteration
#     591             assert (node == 'output' and self.outputs[i] is r) or (node.inputs[i] is r)
# --> 592             self.change_input(node, i, new_r, reason=reason)
#     593
#     594         # sometimes the following is triggered.  If you understand why, please explain to James.
#
# /root/anaconda2/lib/python2.7/site-packages/theano/gof/fg.pyc in change_input(self, node, i, new_r, reason)
#     535         # transaction will be reverted later.
#     536         self.execute_callbacks('on_change_input', node, i,
# --> 537                                r, new_r, reason=reason)
#     538         if prune:
#     539             self.__remove_clients__(r, [], True)
#
# /root/anaconda2/lib/python2.7/site-packages/theano/gof/fg.pyc in execute_callbacks(self, name, *args, **kwargs)
#     674                 continue
#     675             tf0 = time.time()
# --> 676             fn(self, *args, **kwargs)
#     677             self.execute_callbacks_times[feature] += time.time() - tf0
#     678         self.execute_callbacks_time += time.time() - t0
#
# /root/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.pyc in on_change_input(self, fgraph, node, i, r, new_r, reason)
#    1325         # This tells us that r and new_r must have the same shape if
#    1326         # we didn't know that the shapes are related, now we do.
# -> 1327         self.update_shape(new_r, r)
#    1328
#    1329         # change_input happens in two cases:
#
# /root/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.pyc in update_shape(self, r, other_r)
#    1199                     self.lscalar_one.equals(
#    1200                         T.extract_constant(merged_shape[i]))
# -> 1201                     for i in xrange(r.ndim)])
#    1202         self.shape_of[r] = tuple(merged_shape)
#    1203         for sv in self.shape_of[r]:
#
# /root/anaconda2/lib/python2.7/site-packages/theano/tensor/var.pyc in equals(self, other)
#     893             other = theano.tensor.basic.constant(other)
#     894         return (isinstance(other, TensorConstant) and
# --> 895                 self.signature() == other.signature())
#     896
#     897     def __copy__(self):
#
# /root/anaconda2/lib/python2.7/site-packages/theano/tensor/var.pyc in __eq__(self, other)
#     803             # False, which is why we do not bother with testing `other.has_nan`
#     804             # here).
# --> 805             return (self.sum == other.sum) and numpy.all(d0 == d1)
#     806
#     807     def __hash__(self):
#
# /root/anaconda2/lib/python2.7/site-packages/theano/tensor/var.pyc in _get_sum(self)
#     818             return self._sum
#     819         except AttributeError:
# --> 820             self._sum = self.no_nan.sum()
#     821             # The following 2 lines are needede as in Python 3.3 with NumPy
#     822             # 1.7.1, numpy.ndarray and numpy.memmap aren't hashable.
#
# /root/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.pyc in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# KeyboardInterrupt:

# %%
out = feature_inversion(thismodel,['LGN','V1s','V1c','MT'])
# Out:
# Running layer:  LGN
# Running layer:  V1s
# Running layer:  V1c
# Running layer:  MT

# %%
visualize_matrix(out[0][0,:,:,:],interval_len=1000,ubound=255)
#visualize_grid(np.expand_dims(out[0],axis=1),ubound=255)
# Out:
# <img src="data:image/png;base64,...">

# %%
for feat in range(4):
    imsave(fpath+"lgn_1_%i.pdf" % feat, out[0][feat,0,:,:],vmin=0,vmax=255,cmap=cm.gray)
    imsave(fpath+"v1s_1_%i.pdf" % feat, out[1][feat,0,:,:],vmin=0,vmax=255,cmap=cm.gray)
    imsave(fpath+"v1c_1_%i.pdf" % feat, out[2][feat,0,:,:],vmin=0,vmax=255,cmap=cm.gray)
    for t in range(16): # we have to split out a png for each element of the feature gif
        imsave(ipath + "feat%i_%02i.png" % (feat,t), out[3][feat,t,:,:],vmin=0,vmax=255,cmap=cm.gray)
