# %%
from assets.opticflowmotion import *
# %load_ext autoreload  
# %autoreload 2
# %matplotlib nbagg

# %%
c = opticflowmotion(64,64,128,50,1)
c.gen()
c.plot()
# Out:
# [[37]
#  [ 9]
#  [25]
#  [51]
#  [19]
#  [51]
#  [43]
#  [13]
#  [19]
#  [20]
#  [34]
#  [27]
#  [ 5]
#  [59]
#  [27]
#  [ 3]
#  [47]
#  [47]
#  [55]
#  [47]
#  [ 6]
#  [62]
#  [24]
#  [41]
#  [61]
#  [21]
#  [42]
#  [12]
#  [53]
#  [52]
#  [ 6]
#  [22]
#  [21]
#  [51]
#  [ 4]
#  [52]
#  [43]
#  [ 3]
#  [32]
#  [53]
#  [18]
#  [60]
#  [59]
#  [12]
#  [28]
#  [ 0]
#  [26]
#  [18]
#  [18]
#  [45]]
# [[39]
#  [ 2]
#  [ 6]
#  [23]
#  [15]
#  [ 8]
#  [32]
#  [30]
#  [19]
#  [53]
#  [60]
#  [28]
#  [62]
#  [55]
#  [10]
#  [63]
#  [16]
#  [37]
#  [57]
#  [14]
#  [ 9]
#  [19]
#  [27]
#  [38]
#  [10]
#  [63]
#  [50]
#  [43]
#  [55]
#  [55]
#  [33]
#  [44]
#  [58]
#  [44]
#  [ 2]
#  [35]
#  [42]
#  [ 3]
#  [60]
#  [17]
#  [56]
#  [26]
#  [39]
#  [59]
#  [13]
#  [63]
#  [25]
#  [61]
#  [15]
#  [40]]
# <img src="data:image/png;base64,...">
