# %%
from assets.opticflowmotion import *
# %load_ext autoreload  
# %autoreload 2
# %matplotlib nbagg

# %%
c = opticflowmotion(64,64,128,50,2)
c.gen()
c.plot()
# Out:
# <img src="data:image/png;base64,...">
