# %%
from assets.motion import *
from assets.gen_motion import *
from assets.vis_utils import *
import matplotlib as plt
# %load_ext autoreload
# %autoreload 2
# %matplotlib nbagg
# Out:
# Using Theano backend.
# /root/anaconda2/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")
# Using Theano backend.

# %%
angles = [0,math.pi/4,math.pi/2,math.pi*3/4,math.pi,math.pi*5/4,math.pi*3/2,math.pi*7/4]
true_spd = 3
true_coh = 1
true_con = 0.5
true_dot = 15
true_noi = 75
X_train_low,Y_train_low,_,_,_,_ = gen_dataset((16,64,64),1,None,['translate'],[true_spd],angles,[true_coh],[true_dot],[0],dot_radius=2,contrast=true_con,Snoise=true_noi,retina=0)

# %%
visualize_matrix(X_train_low[np.random.randint(8),0,:,:,:],interval_len=50,ubound=255)
# Out:
# <img src="data:image/png;base64,...">

# %%
# testing generating a gaussian matrix
dr = 2
maxC = 255
dot_mat = np.zeros((6*dr+1,6*dr+1)) # goes out 3*dr in both directions from center point
cx = 3*dr
cy = 3*dr
for x in range(6*dr+1):
    for y in range(6*dr+1):
        dist = math.sqrt(math.pow(x-cx,2) + math.pow(y-cy,2))
        dot_mat[x,y] = maxC*math.exp(-math.pow(dist/dr,2))
dot_mat = np.expand_dims(dot_mat,axis=0)
print dot_mat.shape
# Out:
# (1, 13, 13)

# %%
visualize_matrix(dot_mat,ubound=255)
# Out:
# <img src="data:image/png;base64,...">
