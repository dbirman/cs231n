# %%
from assets.motion import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib nbagg

# %%
import time
t = time.time()
c = Translate(32,32,16,10,1,np.pi*2,0.5,0.5)
c.gen()
elapsed = time.time() - t
print elapsed
c.plot()
# Out:
# 0.108945131302
# <img src="data:image/png;base64,...">

# %%
a = np.random.rand(100,1)
c = np.random.rand(100,1)<.5

# %%
(c==False).shape
# Out:
# (100L, 1L)
