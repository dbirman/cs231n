# %%
from assets.motion import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib nbagg
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
c = Translate(64,64,32,1,1,np.pi)
c.gen()
a = c.plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
# Out:
# <img src="data:image/png;base64,...">
