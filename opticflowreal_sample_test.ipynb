# %% [markdown]
# ###Setup
# author: steeve laquitaine

# %%
from assets.opticflowreal import *
# %load_ext autoreload  
# %autoreload 2
# %matplotlib nbagg
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Run optic flow

# %%
c = opticflowreal(64,64,128,100,velocity=1.1,coherence=1,direction=1)
c.gen()
c.plot()
# Out:
# <img src="data:image/png;base64,...">
