# %%
from object_motion import *
from motion import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib nbagg
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import math

# %%
t,x,y = (128,64,64)
backg_vel = 1
backg_theta = 0
backg_coh = 0
backg_n = 100
obj_mask = mask_square(11,11)
#obj_mask = mask_donut(25,25,4)
#obj_mask = mask_circle(25,25,4)
obj_vel = 1
obj_theta = 0

mot = Translate(x,y,t,backg_n,backg_vel,backg_theta,backg_coh)
obj = Object_Motion(obj_mask,obj_vel,obj_theta)

# %%
obj.gen(mot.gen())
obj.plot()
# Out:
# object_motion.py:89: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   ax = plt.gca()
# <img src="data:image/png;base64,...">

# %%
# Now draw a circle
obj_mask = mask_donut(11,11,5)
print obj_mask
# Out:
# [[   0.    0.    0.    0.    0.  255.    0.    0.    0.    0.    0.]
#  [   0.    0.    0.    0.  255.  245.  255.    0.    0.    0.    0.]
#  [   0.    0.    0.    0.  245.  217.  245.    0.    0.    0.    0.]
#  [   0.    0.    0.    0.  217.    0.  217.    0.    0.    0.    0.]
#  [   0.    0.    0.  255.    0.    0.    0.  255.    0.    0.    0.]
#  [   0.    0.    0.  245.    0.    0.    0.  245.    0.    0.    0.]
#  [   0.    0.    0.  255.    0.    0.    0.  255.    0.    0.    0.]
#  [   0.    0.    0.    0.  217.    0.  217.    0.    0.    0.    0.]
#  [   0.    0.    0.    0.  245.  217.  245.    0.    0.    0.    0.]
#  [   0.    0.    0.    0.  255.  245.  255.    0.    0.    0.    0.]
#  [   0.    0.    0.    0.    0.  255.    0.    0.    0.    0.    0.]]

# %%
np.exp(-5**2)
# Out:
# 1.3887943864964021e-11
